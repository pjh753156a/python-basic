# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 다중 인덱스
# 데이터프레임에 여러 계층을 가지는 인덱스를 지정할 수 있음
# 데이터프레임 생성시 `columns` 인수로 다차원 리스트 형태를 지정하면 다중 인덱스로 지정할 수 있음

# %%
df = pd.DataFrame(np.random.randn(5, 4).round(2), columns=[['A', 'A', 'B', 'B'], ['C1', 'C2', 'C1', 'C2']])

df
# Out:
#       A           B
#      C1    C2    C1    C2
# 0  0.33 -0.10 -1.04  0.46
# 1 -0.59 -1.60 -1.23  0.58
# 2  0.59 -1.78 -1.39 -0.67
# 3  1.72  0.47 -0.32 -0.22
# 4 -0.73 -0.02 -1.97  0.71

# %% [markdown]
# 데이터프레임의 `columns` 속성의 `names` 속성으로 각 열 인덱스에 대한 이름을 부여할 수 있음

# %%
df.columns.names = ['Cidx1', 'Cidx2']
df
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C1    C2
# 0      0.33 -0.10 -1.04  0.46
# 1     -0.59 -1.60 -1.23  0.58
# 2      0.59 -1.78 -1.39 -0.67
# 3      1.72  0.47 -0.32 -0.22
# 4     -0.73 -0.02 -1.97  0.71

# %% [markdown]
# 데이터프레임 생성 시 `index` 인수로 다차원 리스트를 지정하면 다차원 형태의 행 인덱스를 지정할 수 있음
# 행 인덱스의 이름은 데이터프레임 인스턴스의 `index` 속성의 `names` 속성으로 지정할 수 있음

# %%
df2 = pd.DataFrame(np.random.randn(6, 4).round(2), 
            columns=[['A', 'A', 'B', 'B'], ['C1', 'C2', 'C1', 'C2']],
            index=[['M', 'M', 'M', 'F', 'F', 'F'], ['id_1', 'id_2', 'id_3', 'id_1', 'id_2', 'id_3']])
df2
# Out:
#            A           B
#           C1    C2    C1    C2
# M id_1  0.87 -0.71  2.55  0.84
#   id_2 -1.17  1.44 -0.04  0.35
#   id_3  0.59 -0.52 -0.89  0.73
# F id_1 -0.44 -0.32  1.53  0.67
#   id_2  0.29  1.31  1.56 -0.73
#   id_3 -1.05 -1.11 -1.34 -0.82

# %%
df2.index.names = ['Ridx1', 'Ridx2']
df2.columns.names = ['Cidx1', 'Cidx2']
df2
# Out:
# Cidx1           A           B
# Cidx2          C1    C2    C1    C2
# Ridx1 Ridx2
# M     id_1   0.87 -0.71  2.55  0.84
#       id_2  -1.17  1.44 -0.04  0.35
#       id_3   0.59 -0.52 -0.89  0.73
# F     id_1  -0.44 -0.32  1.53  0.67
#       id_2   0.29  1.31  1.56 -0.73
#       id_3  -1.05 -1.11 -1.34 -0.82

# %% [markdown]
# ### 열 인덱스와 행 인덱스 교환
# `stack`, `unstack` 메서드로 열 인덱스를 행 인덱스로 또는 행 인덱스를 열 인덱스로 바꿀 수 있음
# `stack()` 메서드 : 열 인덱스를 행 인덱스로 변경
# `unstack()` 메서드 : 행 인덱스를 열 인덱스로 변경

# %%
df2.stack('Cidx1')
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_7572\3173744584.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2.stack('Cidx1')
# Cidx2                C1    C2
# Ridx1 Ridx2 Cidx1
# M     id_1  A      0.87 -0.71
#             B      2.55  0.84
#       id_2  A     -1.17  1.44
#             B     -0.04  0.35
#       id_3  A      0.59 -0.52
#             B     -0.89  0.73
# F     id_1  A     -0.44 -0.32
#             B      1.53  0.67
#       id_2  A      0.29  1.31
#             B      1.56 -0.73
#       id_3  A     -1.05 -1.11
#             B     -1.34 -0.82

# %%
df3 = df2.stack(1)
df3
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_7572\4246712737.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df3 = df2.stack(1)
# Cidx1                 A     B
# Ridx1 Ridx2 Cidx2
# M     id_1  C1     0.87  2.55
#             C2    -0.71  0.84
#       id_2  C1    -1.17 -0.04
#             C2     1.44  0.35
#       id_3  C1     0.59 -0.89
#             C2    -0.52  0.73
# F     id_1  C1    -0.44  1.53
#             C2    -0.32  0.67
#       id_2  C1     0.29  1.56
#             C2     1.31 -0.73
#       id_3  C1    -1.05 -1.34
#             C2    -1.11 -0.82

# %%
df4 = df2.unstack(1)
df4
# Out:
# Cidx1     A                                   B
# Cidx2    C1                C2                C1                C2
# Ridx2  id_1  id_2  id_3  id_1  id_2  id_3  id_1  id_2  id_3  id_1  id_2  id_3
# Ridx1
# F     -0.44  0.29 -1.05 -0.32  1.31 -1.11  1.53  1.56 -1.34  0.67 -0.73 -0.82
# M      0.87 -1.17  0.59 -0.71  1.44 -0.52  2.55 -0.04 -0.89  0.84  0.35  0.73

# %%
df4.unstack(0)
# Out:
# Cidx1  Cidx2  Ridx2  Ridx1
# A      C1     id_1   F       -0.44
#                      M        0.87
#               id_2   F        0.29
#                      M       -1.17
#               id_3   F       -1.05
#                      M        0.59
#        C2     id_1   F       -0.32
#                      M       -0.71
#               id_2   F        1.31
#                      M        1.44
#               id_3   F       -1.11
#                      M       -0.52
# B      C1     id_1   F        1.53
#                      M        2.55
#               id_2   F        1.56
#                      M       -0.04
#               id_3   F       -1.34
#                      M       -0.89
#        C2     id_1   F        0.67
#                      M        0.84
#               id_2   F       -0.73
#                      M        0.35
#               id_3   F       -0.82
#                      M        0.73
# dtype: float64

# %% [markdown]
# ### 다중 인덱스의 인덱싱
# 다중 인덱스를 가지고 있는 데이터프레임의 경우 하나의 인덱스가 아니라 `()`로 둘러쌓인 튜플이어야 함

# %%
df
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C1    C2
# 0      0.33 -0.10 -1.04  0.46
# 1     -0.59 -1.60 -1.23  0.58
# 2      0.59 -1.78 -1.39 -0.67
# 3      1.72  0.47 -0.32 -0.22
# 4     -0.73 -0.02 -1.97  0.71

# %%
df[('A', 'C2')]
# Out:
# 0   -0.10
# 1   -1.60
# 2   -1.78
# 3    0.47
# 4   -0.02
# Name: (A, C2), dtype: float64

# %%
df.loc[0, ('A', 'C1')]
# Out:
# 0.33

# %% [markdown]
# 만약 튜플로 지정하지 않고 단일 값으로 지정하면 제일 최상단의 인덱스를 지정한 것으로 봄

# %%
df['A']
# Out:
# Cidx2    C1    C2
# 0      0.33 -0.10
# 1     -0.59 -1.60
# 2      0.59 -1.78
# 3      1.72  0.47
# 4     -0.73 -0.02

# %% [markdown]
# 단, `iloc`인덱서를 사용할 때는 다중인덱스로 접근을 할 수 없음

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2          C1    C2    C1    C2
# Ridx1 Ridx2
# M     id_1   0.87 -0.71  2.55  0.84
#       id_2  -1.17  1.44 -0.04  0.35
#       id_3   0.59 -0.52 -0.89  0.73
# F     id_1  -0.44 -0.32  1.53  0.67
#       id_2   0.29  1.31  1.56 -0.73
#       id_3  -1.05 -1.11 -1.34 -0.82

# %%
df2.loc[('M', 'id_2')]
# Out:
# Cidx1  Cidx2
# A      C1      -1.17
#        C2       1.44
# B      C1      -0.04
#        C2       0.35
# Name: (M, id_2), dtype: float64

# %%
df2.loc[('M', 'id_2'), ('B', 'C1')]
# Out:
# -0.04

# %%
df2.loc[:, ('A', 'C2')]
# Out:
# Ridx1  Ridx2
# M      id_1    -0.71
#        id_2     1.44
#        id_3    -0.52
# F      id_1    -0.32
#        id_2     1.31
#        id_3    -1.11
# Name: (A, C2), dtype: float64

# %%
df2.loc[('All', 'All'), :] = df2.sum()
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2          C1    C2    C1    C2
# Ridx1 Ridx2
# M     id_1   0.87 -0.71  2.55  0.84
#       id_2  -1.17  1.44 -0.04  0.35
#       id_3   0.59 -0.52 -0.89  0.73
# F     id_1  -0.44 -0.32  1.53  0.67
#       id_2   0.29  1.31  1.56 -0.73
#       id_3  -1.05 -1.11 -1.34 -0.82
# All   All   -0.91  0.09  3.37  1.04

# %%
df2.loc['M']
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C1    C2
# Ridx2
# id_1   0.87 -0.71  2.55  0.84
# id_2  -1.17  1.44 -0.04  0.35
# id_3   0.59 -0.52 -0.89  0.73

# %% [markdown]
# 다중인덱스 인덱싱의 튜플 내에서 슬라이싱을 하고 싶다면 `:` 대신 `slice()` 메서드를 사용해야함
# `slice(마지막인덱스)`, `slice(시작인덱스, 마지막인덱스)`, `slice(시작인덱스, 마지막인덱스, 스텝)`

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2          C1    C2    C1    C2
# Ridx1 Ridx2
# M     id_1   0.87 -0.71  2.55  0.84
#       id_2  -1.17  1.44 -0.04  0.35
#       id_3   0.59 -0.52 -0.89  0.73
# F     id_1  -0.44 -0.32  1.53  0.67
#       id_2   0.29  1.31  1.56 -0.73
#       id_3  -1.05 -1.11 -1.34 -0.82
# All   All   -0.91  0.09  3.37  1.04

# %%
df2.loc[('M', slice(None)), :]
# Out:
# Cidx1           A           B
# Cidx2          C1    C2    C1    C2
# Ridx1 Ridx2
# M     id_1   0.87 -0.71  2.55  0.84
#       id_2  -1.17  1.44 -0.04  0.35
#       id_3   0.59 -0.52 -0.89  0.73

# %%
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2.loc[:, ('A', slice(None))]
# Out:
# Cidx1            A
# Cidx2           C1    C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71
#       id_2   -1.17  1.44
#       id_3    0.59 -0.52
# F     id_1   -0.44 -0.32
#       id_2    0.29  1.31
#       id_3   -1.05 -1.11
# All   All   -30.03  2.97

# %% [markdown]
# ### 다중 인덱스의 인덱스 순서 변경
# 다중 인덱스의 순서를 변경하고 싶으면 `swaplevel(i, j, axis)` 메서드를 사용함
# `i`, `j` 인자 : 순서를 변경할 인덱스의 이름 혹은 번호
# `axis`  인자 : 0 일 경우 행 인덱스, 1일 경우 열 인덱스

# %%
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2.swaplevel('Ridx2', 'Ridx1', 0)
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx2 Ridx1
# id_1  M       0.87 -0.71    2.55   0.84
# id_2  M      -1.17  1.44   -0.04   0.35
# id_3  M       0.59 -0.52   -0.89   0.73
# id_1  F      -0.44 -0.32    1.53   0.67
# id_2  F       0.29  1.31    1.56  -0.73
# id_3  F      -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2.swaplevel('Cidx2', 'Cidx1', 1)
# Out:
# Cidx2           C1    C2      C1     C2
# Cidx1            A     A       B      B
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %% [markdown]
# ### 다중 인덱스의 정렬
# 다중 인덱스를 가지고 있는 데이터프레임에서 `sort_index`로 정렬할 때 `level` 인수를 사용하여 어떤 인덱스 기준으로 정렬할지 지정해야함

# %%
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2.sort_index(level=0)
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# All   All   -30.03  2.97  111.21  34.32
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73

# %%
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2.sort_index(level=(1, 0))
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# All   All   -30.03  2.97  111.21  34.32
# F     id_1   -0.44 -0.32    1.53   0.67
# M     id_1    0.87 -0.71    2.55   0.84
# F     id_2    0.29  1.31    1.56  -0.73
# M     id_2   -1.17  1.44   -0.04   0.35
# F     id_3   -1.05 -1.11   -1.34  -0.82
# M     id_3    0.59 -0.52   -0.89   0.73

# %%
df2
# Out:
# Cidx1            A             B
# Cidx2           C1    C2      C1     C2
# Ridx1 Ridx2
# M     id_1    0.87 -0.71    2.55   0.84
#       id_2   -1.17  1.44   -0.04   0.35
#       id_3    0.59 -0.52   -0.89   0.73
# F     id_1   -0.44 -0.32    1.53   0.67
#       id_2    0.29  1.31    1.56  -0.73
#       id_3   -1.05 -1.11   -1.34  -0.82
# All   All   -30.03  2.97  111.21  34.32

# %%
df2.sort_index(level=1, axis=1)
# Out:
# Cidx1            A       B     A      B
# Cidx2           C1      C1    C2     C2
# Ridx1 Ridx2
# M     id_1    0.87    2.55 -0.71   0.84
#       id_2   -1.17   -0.04  1.44   0.35
#       id_3    0.59   -0.89 -0.52   0.73
# F     id_1   -0.44    1.53 -0.32   0.67
#       id_2    0.29    1.56  1.31  -0.73
#       id_3   -1.05   -1.34 -1.11  -0.82
# All   All   -30.03  111.21  2.97  34.32

# %% [markdown]
# ##### 파이썬으로 다음 연산을 수행한다.
# A 반 학생 5명과 B반 학생 5명의 국어, 영어, 수학 점수를 나타내는 데이터프레임을 다음과 같이 만든다.
# 1. “반”, “번호”, “국어”, “영어”, “수학” 을 열로 가지는 데이터프레임 `df_score3`을 만든다.
# 2. `df_score3`을 변형하여 1차 행 인덱스로 “반”을 2차 행 인덱스로 “번호”을 가지는 데이터프레임 `df_score4`을 만든다.
# 3. 데이터 프레임 `df_score4`에 각 학생의 평균을 나타내는 열을 오른쪽에 추가한다.
# 4. `df_score3`을 변형하여 행 인덱스로 “번호”를, 1차 열 인덱스로 “국어”, “영어”, “수학”을, 2차 열 인덱스로 “반”을 가지는 데이터프레임 `df_score5`을 만든다.
# 5. 데이터 프레임 `df_score5`에 각 반별 각 과목의 평균을 나타내는 행을 아래에 추가한다.

# %%
df_score3 = pd.DataFrame({
    '반': [1, 1, 1, 2, 2, 2],
    '번호': [1, 2, 3, 1, 2, 3],
    '국어': [60, 80, 90, 70, 100, 50],
    '영어': [70, 50, 90, 60, 100, 80],
    '수학': [80, 70, 50, 90, 60, 100]
})
df_score3
# Out:
#    반  번호   국어   영어   수학
# 0  1   1   60   70   80
# 1  1   2   80   50   70
# 2  1   3   90   90   50
# 3  2   1   70   60   90
# 4  2   2  100  100   60
# 5  2   3   50   80  100

# %%
df_score4 = df_score3.set_index(['반', '번호'])
df_score4
# Out:
#        국어   영어   수학
# 반 번호
# 1 1    60   70   80
#   2    80   50   70
#   3    90   90   50
# 2 1    70   60   90
#   2   100  100   60
#   3    50   80  100

# %% [markdown]
# 3. 데이터 프레임 `df_score4`에 각 학생의 평균을 나타내는 열을 오른쪽에 추가한다.
# 4. `df_score3`을 변형하여 행 인덱스로 “번호”를, 1차 열 인덱스로 “국어”, “영어”, “수학”을, 2차 열 인덱스로 “반”을 가지는 데이터프레임 `df_score5`을 만든다.
# 5. 데이터 프레임 `df_score5`에 각 반별 각 과목의 평균을 나타내는 행을 아래에 추가한다.

# %%
df_score4
# Out:
#        국어   영어   수학     평균
# 반 번호
# 1 1    60   70   80  70.00
#   2    80   50   70  66.67
#   3    90   90   50  76.67
# 2 1    70   60   90  73.33
#   2   100  100   60  86.67
#   3    50   80  100  76.67

# %%
df_score4['평균'] = df_score4.mean(axis=1).round(2)
df_score4
# Out:
#        국어   영어   수학     평균
# 반 번호
# 1 1    60   70   80  70.00
#   2    80   50   70  66.67
#   3    90   90   50  76.67
# 2 1    70   60   90  73.33
#   2   100  100   60  86.67
#   3    50   80  100  76.67

# %% [markdown]
# 4. `df_score3`을 변형하여 행 인덱스로 “번호”를, 1차 열 인덱스로 “국어”, “영어”, “수학”을, 2차 열 인덱스로 “반”을 가지는 데이터프레임 `df_score5`을 만든다.
# 5. 데이터 프레임 `df_score5`에 각 반별 각 과목의 평균을 나타내는 행을 아래에 추가한다.

# %%
df_score3
# Out:
#    반  번호   국어   영어   수학
# 0  1   1   60   70   80
# 1  1   2   80   50   70
# 2  1   3   90   90   50
# 3  2   1   70   60   90
# 4  2   2  100  100   60
# 5  2   3   50   80  100

# %%
df_score3.set_index(['반', '번호'])
# Out:
#        국어   영어   수학
# 반 번호
# 1 1    60   70   80
#   2    80   50   70
#   3    90   90   50
# 2 1    70   60   90
#   2   100  100   60
#   3    50   80  100

# %%
df_score5 = df_score3.set_index(['반', '번호']).unstack('반')
df_score5
# Out:
#     국어       영어       수학
# 반    1    2   1    2   1    2
# 번호
# 1   60   70  70   60  80   90
# 2   80  100  50  100  70   60
# 3   90   50  90   80  50  100

# %%
df_score5.loc['평균', :] = df_score5.mean().round(2)
df_score5
# Out:
#        국어            영어            수학
# 반       1       2     1      2      1       2
# 번호
# 1   60.00   70.00  70.0   60.0  80.00   90.00
# 2   80.00  100.00  50.0  100.0  70.00   60.00
# 3   90.00   50.00  90.0   80.0  50.00  100.00
# 평균  76.67   73.33  70.0   80.0  66.67   83.33
